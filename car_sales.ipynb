# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import converter
import joblib

# %%
model = joblib.load('cars-gender-model.joblib')
df = pd.read_csv('car_sales_cleaned1.csv')
mapper = converter.columnsMapper(["Company","Model","Transmission"], df)
predictions = model.predict([[mapper["Company"]["Hyundai"], -1, mapper["Transmission"]["Auto"]]])
predictions
# Out:
# C:\Users\User\miniconda3\envs\ai_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Male'], dtype=object)
