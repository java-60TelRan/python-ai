# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
model = YOLO("runs\\detect\\circle_square_exp\\weights\\best.pt")
results = model("shapes1.jpg")
annotated = results[0].plot()
plt.imshow(annotated)
plt.show()
# Out:
# image 1/1 c:\Users\User\Documents\Java_60\back-end\python-ai\shapes1.jpg: 256x224 1 circle, 6 squares, 239.3ms
# Speed: 2.0ms preprocess, 239.3ms inference, 4.6ms postprocess per image at shape (1, 3, 256, 224)
