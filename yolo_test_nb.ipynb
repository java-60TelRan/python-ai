# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
model = YOLO("yolov8m.pt")
results = model('street.jpg')
img_annotated = results[0].plot()
plt.figure(figsize=(10,8))
plt.imshow(img_annotated)
plt.title("Detection Objects")
plt.axis("off")
plt.show()
# Out:
# image 1/1 c:\Users\User\Documents\Java_60\back-end\python-ai\street.jpg: 640x512 5 persons, 1 bicycle, 2 cars, 1 backpack, 3 suitcases, 1755.3ms
# Speed: 7.8ms preprocess, 1755.3ms inference, 25.9ms postprocess per image at shape (1, 3, 640, 512)

# %%
model = YOLO("yolov8m-seg.pt")
results = model('street.jpg')
img_annotated = results[0].plot()
plt.figure(figsize=(8,10))
plt.imshow(img_annotated)
plt.title("Segmentation Objects")
plt.axis("off")
plt.show()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m-seg.pt to 'yolov8m-seg.pt': 100% ━━━━━━━━━━━━ 52.4MB 493.8KB/s 1:49 1:49<0.0s19
#
# image 1/1 c:\Users\User\Documents\Java_60\back-end\python-ai\street.jpg: 640x512 5 persons, 1 bicycle, 2 cars, 1 handbag, 1 suitcase, 3204.1ms
# Speed: 13.4ms preprocess, 3204.1ms inference, 73.3ms postprocess per image at shape (1, 3, 640, 512)

# %%
model = YOLO("yolov8l-cls.pt")
results = model('street.jpg')
img_annotated = results[0].plot()
plt.figure(figsize=(5,5))
plt.imshow(img_annotated)
plt.title("Image Classification")
plt.axis("off")
plt.show()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8l-cls.pt to 'yolov8l-cls.pt': 100% ━━━━━━━━━━━━ 71.7MB 2.0MB/s 35.5s 35.5s<0.0ss
#
# image 1/1 c:\Users\User\Documents\Java_60\back-end\python-ai\street.jpg: 224x224 cab 0.40, streetcar 0.21, trolleybus 0.15, police_van 0.13, garbage_truck 0.02, 700.0ms
# Speed: 203.7ms preprocess, 700.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)

# %%
import pandas as pd
model = YOLO("yolov8m-seg.pt")
results = model('street.jpg')
boxes = results[0].boxes
xyxy = boxes.xyxy.cpu().numpy()
cls = boxes.cls.cpu().numpy()
conf = boxes.conf.cpu().numpy()
allNames = results[0].names
names = [allNames[c] for c in cls]
df = pd.DataFrame(xyxy, columns=["xmin", "ymin", "xmax", "ymax"])
df["name"] = names
df["confidence"] = conf
df
# Out:
# image 1/1 c:\Users\User\Documents\Java_60\back-end\python-ai\street.jpg: 640x512 5 persons, 1 bicycle, 2 cars, 1 handbag, 1 suitcase, 1586.7ms
# Speed: 11.6ms preprocess, 1586.7ms inference, 54.6ms postprocess per image at shape (1, 3, 640, 512)
#           xmin         ymin         xmax         ymax      name  confidence
# 0  1434.086304  1108.231323  2802.407471  2321.760254       car    0.927583
# 1  1983.624634   247.791199  2424.329834   775.111694   bicycle    0.924828
# 2  1637.375854  3642.001465  1915.706055  3997.941650    person    0.866977
# 3  1973.429199  3402.717285  2269.343506  3997.622314    person    0.836359
# 4   654.490173  2123.347168   956.256592  2823.392578    person    0.810344
# 5   609.579834  1884.156250   805.916626  2404.459961    person    0.787788
# 6  1968.120605    52.143860  2346.071777   498.152557    person    0.726420
# 7   907.741760  2403.661377  1216.744019  2849.966797  suitcase    0.375081
# 8  2723.570801   603.777588  2942.284180  1084.085815       car    0.323316
# 9   558.600220  2554.939941   782.297363  2818.293945   handbag    0.280974
